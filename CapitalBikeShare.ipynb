# %% [markdown]
# #In 200 words or more, describe the architecture of Apache Spark.

# %% [markdown]
# ###Apache Spark is a computing engine which contains multiple API’s, these API’s allow a user to interact using traditional methods with the back-end Spark engine. This compute engine allows a user to create an end to end solution which utilises the distributed capabilities of multiple machines. The Apache Spark framework uses a master-slave architecture that consists of a driver, which runs as a master node, and many executors that run across as worker nodes in the cluster. Apache Spark can be used for batch processing and real-time processing as well.
#
# ###Spark has the capabilities to allow the user to write code in Python, Java, Scala R or SQL, but languages such as Python, and R require the user to install an instance of their relevant interpreter. All Python, R, Scala and SQL are compiled down into Java. PySpark is the Python API for Apache Spark as Spark is written in Scala, and PySpark was released to support the collaboration of Spark and Python. In addition to providing an API for Spark, PySpark helps to interface with Resilient Distributed Datasets (RDDs) by leveraging the Py4j library.
#
# ###Apache Spark provides a suite of Web UI/User Interfaces (Jobs, Stages, Tasks, Storage, Environment, Executors, and SQL) that we can use to monitor the status and resource consumption of Spark cluster.

# %% [markdown]
# #Notebook runs every month for previous month data

# %% [markdown]
# ### Importing the data from Capital Bikeshare into the delta lake.

# %%
import requests
import pandas as pd
from zipfile import ZipFile
import io
import datetime
today = datetime.date.today()
first = today.replace(day=1)
last_month = first - datetime.timedelta(days=1)
last_mon = last_month.strftime("%Y%m")
path="/dbfs/mnt/dev/data/rough/ashok/zip/"
url="https://s3.amazonaws.com/capitalbikeshare-data/"+last_mon+"-capitalbikeshare-tripdata.zip"
response = requests.get(url)
z = ZipFile(io.BytesIO(response.content))
z.extractall(path)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Reading the csv into the dataframe

# %%
from pyspark.sql.functions import *
from pyspark.sql import functions as F
df = spark.read.option("inferschema","true").option("header","true").csv("/mnt/dev/data/rough/ashok/zip")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Dropping latitude related columns

# %%
df_drop_lat_lon = df.drop('start_lat','start_lng','end_lat','end_lng')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Finding the duration of each ride

# %%
df_addingduration = df_drop_lat_lon.withColumn("from_timestamp_time",to_timestamp("started_at")).withColumn("to_timestamp_time",to_timestamp("ended_at"))
df_addingduration = df_addingduration.drop("started_at","ended_at")

df_addingduration = df_addingduration.withColumn('duration',(to_timestamp("to_timestamp_time").cast("long") - to_timestamp('from_timestamp_time').cast("long"))/60)
df_addingduration= df_addingduration.filter(col("from_timestamp_time").isNotNull())
df_addingduration= df_addingduration.filter(col("to_timestamp_time").isNotNull())
display(df_addingduration)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ride_id</th><th>rideable_type</th><th>start_station_name</th><th>start_station_id</th><th>end_station_name</th><th>end_station_id</th><th>member_casual</th><th>from_timestamp_time</th><th>to_timestamp_time</th><th>duration</th></tr></thead><tbody><tr><td>636812F7EDA843A3</td><td>electric_bike</td><td>Fairfax Dr & N Taylor St</td><td>31049</td><td>null</td><td>null</td><td>member</td><td>2022-10-21T07:19:55.000+0000</td><td>2022-10-21T07:32:47.000+0000</td><td>12.866666666666667</td></tr><tr><td>2963CAC314D0C593</td><td>electric_bike</td><td>Eads St & 12th St S</td><td>31071</td><td>null</td><td>null</td><td>member</td><td>2022-10-21T16:52:10.000+0000</td><td>2022-10-21T17:07:43.000+0000</td><td>15.55</td></tr><tr><td>81383A5B7B0DDF3D</td><td>electric_bike</td><td>
# %% [markdown]
# ## Calculating the average duration by ride type

# %%
df_rideable_type_agg = df_addingduration.groupBy('rideable_type').avg("duration")

display(df_rideable_type_agg)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>rideable_type</th><th>avg(duration)</th></tr></thead><tbody><tr><td>docked_bike</td><td>96.36651343989107</td></tr><tr><td>electric_bike</td><td>14.823209690191039</td></tr><tr><td>classic_bike</td><td>19.56327849269697</td></tr></tbody></table></div>

# %% [markdown]
# ## Calculating top 10 ride durations for each start station

# %%
df_over24 = df_over24.filter(col("duration") > 1440)
display(df_over24)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ride_id</th><th>rideable_type</th><th>start_station_name</th><th>start_station_id</th><th>end_station_name</th><th>end_station_id</th><th>member_casual</th><th>from_timestamp_time</th><th>to_timestamp_time</th><th>duration</th></tr></thead><tbody><tr><td>AAF3CE4B95A07891</td><td>classic_bike</td><td>Anacostia Metro</td><td>31801</td><td>null</td><td>null</td><td>casual</td><td>2022-10-19T08:32:50.000+0000</td><td>2022-10-20T09:32:30.000+0000</td><td>1499.6666666666667</td></tr><tr><td>E112C160BE8C758D</td><td>classic_bike</td><td>Gallaudet / 8th St & Florida Ave NE</td><td>31508</td><td>null</td><td>null</td><td>casual</td><td>2022-10-30T18:35:14.000+0000</td><td>2022-10-31T19:34:59.000+0000</td><td>1499.75</td></tr><tr><td>A8A3BB946A74B5CB</td><td>classic_bike</td><td>14th & V St NW</td><td>31101</td><td>null</td><td>null</td><td>member</td><td>2022-10-23T12:08:03.000+0000</td><td>2022-10-24T13:07:58.000+0000</td><td>1499.9166666666667</td></tr><tr><td>1671339A417D2C2F</td><td>classic_bike</td><td>Pleasant St & MLK Ave SE</td><td>31807</td><td>null</td><td>null</td><td>casual</td><td>2022-10-10T14:48:49.000+0000</td><td>2022-10-11T15:48:42.000+0000</td><td>1499.8833333333334</td></tr><tr><td>22461B1698F1EB78</td><td>classic_bike</td><td>13th & U St NW</td><td>31132</td><td>null</td><td>null</td><td>member</td><td>2022-10-16T01:58:13.000+0000</td><td>2022-10-17T02:58:09.000+0000</td><td>1499.9333333333334</td></tr><tr><td>D2BF4730B5497986</td><td>classic_bike</td><td>N Oak St & W Broad St</td><td>32602</td><td>null</td><td>null</td><td>casual</td><td>2022-10-20T10:29:21.000+0000</td><td>2022-10-21T11:29:16.000+0000</td><td>1499.9166666666667</td></tr><tr><td>CC202332FB2597EB</td><td>docked_bike</td><td>N Veitch St & 20th St N</td><td>31029</td><td>null</td><td>null</td><td>casual</td><td>2022-10-01T22:07:54.000+0000</td><td>2022-10-02T23:07:55.000+0000</td><td>1500.0166666666667</td></tr><tr><td>A44BF903A9453640</td><td>classic_bike</td><td>The Mall at Prince Georges</td><td>32422</td><td>null</td><td>null</td><td>member</td><td>2022-10-29T19:58:18.000+0000</td><td>2022-10-30T20:58:12.000+0000</td><td>1499.9</td></tr><tr><td>DDF728A706308277</td><td>docked_bike</td><td